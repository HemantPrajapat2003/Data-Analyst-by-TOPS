# %%
# 1.
# Write a recursive function in Python called reverse_string(s) that takes a string and returns 
# it reversed (e.g., 'hello' becomes 'olleh').
def reverse_string(s):
    if len(s) == 0:
        return s
    return reverse_string(s[1:]) + s[0]

print(reverse_string("hello"))
# Out:
# olleh

# %%
# 2.
# Build a recursive function sum_playlist_durations(durations) that takes a list of song durations
#  (in seconds) and returns the total duration, similar to how Spotify totals a playlist.

def  sum_playlist_durations(durations):
    if len(durations) == 0:
        return 0
    return durations[0] + sum_playlist_durations(durations[1:])

songs = [200, 180, 280, 150]

print(sum_playlist_durations(songs))
# Out:
# 810

# %%
# 3.
# Given the following code, identify whether the variable 'count' is local or global in each function, and explain what will be printed when run:

count = 10

def update_count():
    count = 5
    print('Inside:', count)

update_count()
print('Outside:', count)
# Out:
# Inside: 5
# Outside: 10

# %%
# 4.
# Create a recursive function count_likes(posts) that takes a nested dictionary representing Instagram posts
#  and their replies (each with a 'likes' key), and returns the total number of likes across all posts and
#  replies.<br><br><em><strong>Hint:</strong> Each reply can itself have more replies, so use recursion to
#  sum likes at all levels.</em>

def count_likes(post):
    total = post["likes"]

    for reply in post["replies"]:
        total += count_likes(reply)

    return total

data = {"likes": 10, "replies" :[{"likes": 5, "replies": []},
                                 {"likes": 3, "replies": [{"likes": 2, "replies": []}]}]}

print(count_likes(data))
# Out:
# 20

# %%
# 5.
# Write a Python script that demonstrates the lifetime of a local variable inside a function versus a
#  global variable by printing their values before, during, and after a function call. Use variable names
#  similar to 'user_status' and 'app_status', inspired by WhatsApp online/offline status.

app_status = "Online"  # global variable

def check_status():
    user_status = "Typing..."  # local variable
    print("Inside function:")
    print("User Status:", user_status)
    print("App Status:", app_status)

print("Before function:")
print("App Status:", app_status)

check_status()

print("After function:")
print("App Status:", app_status)
# Out:
# Before function:
# App Status: Online
# Inside function:
# User Status: Typing...
# App Status: Online
# After function:
# App Status: Online
